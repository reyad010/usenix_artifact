# %%
import json
import os
import glob

# %%
# Get all cha_events_<arch>.json files in the current directory, skipping parsed files
json_files = [f for f in glob.glob("cha_events_*.json") if "_parsed.json" not in f]

for json_file_path in json_files:
    with open(json_file_path, "r") as file:
        data = json.load(file)

    # Dictionary to group events by EventCode
    event_groups = {}
    event_index_map = {}

    for index, event in enumerate(data):
        if "This event is deprecated" in event.get("BriefDescription", ""):
            print(f"Skipping deprecated event at index {index}: {event}")
        if event.get("Deprecated", "0") == "1" or "This event is deprecated" in event.get("BriefDescription", ""):
            continue  # Skip deprecated events
        
        # Ensure EventCode exists before processing
        if "EventCode" not in event:
            print(f"Skipping event at index {index} due to missing EventCode: {event}")
            continue
        
        event_code = event["EventCode"]
        event_name = event["EventName"].rsplit(".", 1)[0]  # Remove sub-event suffix if present
        umask = int(event.get("UMask", "0"), 16)  # Default to 0x00 if UMask is missing

        if event_code not in event_groups:
            event_groups[event_code] = {}

        if event_name not in event_groups[event_code]:
            event_groups[event_code][event_name] = []
        
        event_groups[event_code][event_name].append(umask)
        event_index_map[(event_code, event_name)] = index  # Track last occurrence of event

    # Insert new events immediately after their last corresponding event
    offset = 0
    for (event_code, event_name), last_index in event_index_map.items():
        if len(event_groups[event_code][event_name]) > 1:
            combined_umask = 0
            for umask in event_groups[event_code][event_name]:
                combined_umask |= umask  # Perform bitwise OR
            
            new_event = {
                "BriefDescription": f"Aggregated event for {event_name}",
                "EventCode": event_code,
                "EventName": f"{event_name}.ALL_UMASK",
                "UMask": hex(combined_umask),
                "Unit": "CHA"
            }
            insert_index = last_index + 1 + offset
            data.insert(insert_index, new_event)
            offset += 1

    # Save the updated data to a new file
    output_file_path = json_file_path.replace(".json", "_parsed.json")
    with open(output_file_path, "w") as file:
        json.dump(data, file, indent=4)

    print(f"Updated JSON file saved to {output_file_path}")
# Out:
# Skipping event at index 51 due to missing EventCode: {'BriefDescription': 'Clockticks of the uncore caching & home agent (CHA)', 'Counter': '0,1,2,3', 'EventName': 'UNC_CHA_CLOCKTICKS', 'PerPkg': '1', 'PublicDescription': 'Counts clockticks of the clock controlling the uncore caching and home agent (CHA).', 'Unit': 'CHA'}
# Skipping deprecated event at index 129: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_LLC_VICTIMS.TOTAL_E', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x37', 'EventName': 'UNC_CHA_LLC_VICTIMS.E_STATE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 130: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_LLC_VICTIMS.TOTAL_F', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x37', 'EventName': 'UNC_CHA_LLC_VICTIMS.F_STATE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 131: {'BriefDescription': 'This event is deprecated.', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x37', 'EventName': 'UNC_CHA_LLC_VICTIMS.LOCAL', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x20', 'Unit': 'CHA'}
# Skipping deprecated event at index 137: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_LLC_VICTIMS.TOTAL_M', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x37', 'EventName': 'UNC_CHA_LLC_VICTIMS.M_STATE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 138: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_LLC_VICTIMS.REMOTE_ALL', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x37', 'EventName': 'UNC_CHA_LLC_VICTIMS.REMOTE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x80', 'Unit': 'CHA'}
# Skipping deprecated event at index 144: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_LLC_VICTIMS.TOTAL_S', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x37', 'EventName': 'UNC_CHA_LLC_VICTIMS.S_STATE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 436: {'BriefDescription': 'This event is deprecated.', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_CHA_TOR_INSERTS.IPQ_HIT', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x18', 'Unit': 'CHA'}
# Skipping deprecated event at index 437: {'BriefDescription': 'This event is deprecated.', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_CHA_TOR_INSERTS.IPQ_MISS', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x28', 'Unit': 'CHA'}
# Skipping deprecated event at index 439: {'BriefDescription': 'This event is deprecated.', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_CHA_TOR_INSERTS.LOC_ALL', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x37', 'Unit': 'CHA'}
# Skipping deprecated event at index 442: {'BriefDescription': 'This event is deprecated.', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_CHA_TOR_INSERTS.REM_ALL', 'PerPkg': '1', 'UMask': '0x30', 'Unit': 'CHA'}
# Skipping deprecated event at index 443: {'BriefDescription': 'This event is deprecated.', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_CHA_TOR_INSERTS.RRQ_HIT', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x50', 'Unit': 'CHA'}
# Skipping deprecated event at index 444: {'BriefDescription': 'This event is deprecated.', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_CHA_TOR_INSERTS.RRQ_MISS', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x60', 'Unit': 'CHA'}
# Skipping deprecated event at index 445: {'BriefDescription': 'This event is deprecated.', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_CHA_TOR_INSERTS.WBQ_HIT', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x90', 'Unit': 'CHA'}
# Skipping deprecated event at index 446: {'BriefDescription': 'This event is deprecated.', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_CHA_TOR_INSERTS.WBQ_MISS', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0xa0', 'Unit': 'CHA'}
# Skipping deprecated event at index 474: {'BriefDescription': 'This event is deprecated.', 'Counter': '0', 'Deprecated': '1', 'EventCode': '0x36', 'EventName': 'UNC_CHA_TOR_OCCUPANCY.IPQ_HIT', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x18', 'Unit': 'CHA'}
# Skipping deprecated event at index 475: {'BriefDescription': 'This event is deprecated.', 'Counter': '0', 'Deprecated': '1', 'EventCode': '0x36', 'EventName': 'UNC_CHA_TOR_OCCUPANCY.IPQ_MISS', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x28', 'Unit': 'CHA'}
# Skipping deprecated event at index 477: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_OCCUPANCY.ALL_FROM_LOC', 'Counter': '0', 'Deprecated': '1', 'EventCode': '0x36', 'EventName': 'UNC_CHA_TOR_OCCUPANCY.LOC_ALL', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x37', 'Unit': 'CHA'}
# Skipping deprecated event at index 638: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_CLOCKTICKS', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventName': 'UNC_C_CLOCKTICKS', 'PerPkg': '1', 'Unit': 'CHA'}
# Skipping deprecated event at index 639: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_FAST_ASSERTED.HORZ', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xA5', 'EventName': 'UNC_C_FAST_ASSERTED', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 640: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_LLC_LOOKUP.ANY', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x34', 'EventName': 'UNC_C_LLC_LOOKUP.ANY', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x11', 'Unit': 'CHA'}
# Skipping deprecated event at index 641: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_LLC_LOOKUP.DATA_READ', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x34', 'EventName': 'UNC_C_LLC_LOOKUP.DATA_READ', 'PerPkg': '1', 'UMask': '0x3', 'Unit': 'CHA'}
# Skipping deprecated event at index 642: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_LLC_LOOKUP.LOCAL', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x34', 'EventName': 'UNC_C_LLC_LOOKUP.LOCAL', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x31', 'Unit': 'CHA'}
# Skipping deprecated event at index 643: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_LLC_LOOKUP.REMOTE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x34', 'EventName': 'UNC_C_LLC_LOOKUP.REMOTE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x91', 'Unit': 'CHA'}
# Skipping deprecated event at index 644: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_LLC_LOOKUP.REMOTE_SNOOP', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x34', 'EventName': 'UNC_C_LLC_LOOKUP.REMOTE_SNOOP', 'PerPkg': '1', 'UMask': '0x9', 'Unit': 'CHA'}
# Skipping deprecated event at index 645: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_LLC_LOOKUP.WRITE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x34', 'EventName': 'UNC_C_LLC_LOOKUP.WRITE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x5', 'Unit': 'CHA'}
# Skipping deprecated event at index 646: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_LLC_VICTIMS.TOTAL_E', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x37', 'EventName': 'UNC_C_LLC_VICTIMS.E_STATE', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 647: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_LLC_VICTIMS.TOTAL_F', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x37', 'EventName': 'UNC_C_LLC_VICTIMS.F_STATE', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 648: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_LLC_VICTIMS.LOCAL_ALL', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x37', 'EventName': 'UNC_C_LLC_VICTIMS.LOCAL', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2f', 'Unit': 'CHA'}
# Skipping deprecated event at index 649: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_LLC_VICTIMS.TOTAL_M', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x37', 'EventName': 'UNC_C_LLC_VICTIMS.M_STATE', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 650: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_LLC_VICTIMS.REMOTE_ALL', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x37', 'EventName': 'UNC_C_LLC_VICTIMS.REMOTE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x80', 'Unit': 'CHA'}
# Skipping deprecated event at index 651: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_LLC_VICTIMS.TOTAL_S', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x37', 'EventName': 'UNC_C_LLC_VICTIMS.S_STATE', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 652: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_RING_SRC_THRTL', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xA4', 'EventName': 'UNC_C_RING_SRC_THRTL', 'Experimental': '1', 'PerPkg': '1', 'Unit': 'CHA'}
# Skipping deprecated event at index 653: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_INSERTS.EVICT', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.EVICT', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 654: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_INSERTS.HIT', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.HIT', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x10', 'Unit': 'CHA'}
# Skipping deprecated event at index 655: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_INSERTS.IPQ', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.IPQ', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 656: {'BriefDescription': 'This event is deprecated.', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.IPQ_HIT', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x18', 'Unit': 'CHA'}
# Skipping deprecated event at index 657: {'BriefDescription': 'This event is deprecated.', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.IPQ_MISS', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x28', 'Unit': 'CHA'}
# Skipping deprecated event at index 658: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_INSERTS.IA', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.IRQ', 'PerPkg': '1', 'UMask': '0x31', 'Unit': 'CHA'}
# Skipping deprecated event at index 659: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_INSERTS.IA_HIT', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.IRQ_HIT', 'PerPkg': '1', 'UMask': '0x11', 'Unit': 'CHA'}
# Skipping deprecated event at index 660: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_INSERTS.IA_MISS', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.IRQ_MISS', 'PerPkg': '1', 'UMask': '0x21', 'Unit': 'CHA'}
# Skipping deprecated event at index 661: {'BriefDescription': 'This event is deprecated.', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.LOC_ALL', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x37', 'Unit': 'CHA'}
# Skipping deprecated event at index 662: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_INSERTS.IA', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.LOC_IA', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x31', 'Unit': 'CHA'}
# Skipping deprecated event at index 663: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_INSERTS.IO', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.LOC_IO', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x34', 'Unit': 'CHA'}
# Skipping deprecated event at index 664: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_INSERTS.MISS', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.MISS', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x20', 'Unit': 'CHA'}
# Skipping deprecated event at index 665: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_INSERTS.PRQ', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.PRQ', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 666: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_INSERTS.IO_HIT', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.PRQ_HIT', 'PerPkg': '1', 'UMask': '0x14', 'Unit': 'CHA'}
# Skipping deprecated event at index 667: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_INSERTS.IO_MISS', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.PRQ_MISS', 'PerPkg': '1', 'UMask': '0x24', 'Unit': 'CHA'}
# Skipping deprecated event at index 668: {'BriefDescription': 'This event is deprecated.', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.REM_ALL', 'PerPkg': '1', 'UMask': '0x30', 'Unit': 'CHA'}
# Skipping deprecated event at index 669: {'BriefDescription': 'This event is deprecated.', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.RRQ_HIT', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x50', 'Unit': 'CHA'}
# Skipping deprecated event at index 670: {'BriefDescription': 'This event is deprecated.', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.RRQ_MISS', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x60', 'Unit': 'CHA'}
# Skipping deprecated event at index 671: {'BriefDescription': 'This event is deprecated.', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.WBQ_HIT', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x90', 'Unit': 'CHA'}
# Skipping deprecated event at index 672: {'BriefDescription': 'This event is deprecated.', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x35', 'EventName': 'UNC_C_TOR_INSERTS.WBQ_MISS', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0xa0', 'Unit': 'CHA'}
# Skipping deprecated event at index 673: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_OCCUPANCY.EVICT', 'Counter': '0', 'Deprecated': '1', 'EventCode': '0x36', 'EventName': 'UNC_C_TOR_OCCUPANCY.EVICT', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 674: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_OCCUPANCY.HIT', 'Counter': '0', 'Deprecated': '1', 'EventCode': '0x36', 'EventName': 'UNC_C_TOR_OCCUPANCY.HIT', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x10', 'Unit': 'CHA'}
# Skipping deprecated event at index 675: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_OCCUPANCY.IPQ', 'Counter': '0', 'Deprecated': '1', 'EventCode': '0x36', 'EventName': 'UNC_C_TOR_OCCUPANCY.IPQ', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 676: {'BriefDescription': 'This event is deprecated.', 'Counter': '0', 'Deprecated': '1', 'EventCode': '0x36', 'EventName': 'UNC_C_TOR_OCCUPANCY.IPQ_HIT', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x18', 'Unit': 'CHA'}
# Skipping deprecated event at index 677: {'BriefDescription': 'This event is deprecated.', 'Counter': '0', 'Deprecated': '1', 'EventCode': '0x36', 'EventName': 'UNC_C_TOR_OCCUPANCY.IPQ_MISS', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x28', 'Unit': 'CHA'}
# Skipping deprecated event at index 678: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_OCCUPANCY.IA', 'Counter': '0', 'Deprecated': '1', 'EventCode': '0x36', 'EventName': 'UNC_C_TOR_OCCUPANCY.IRQ', 'PerPkg': '1', 'UMask': '0x31', 'Unit': 'CHA'}
# Skipping deprecated event at index 679: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_OCCUPANCY.IA_HIT', 'Counter': '0', 'Deprecated': '1', 'EventCode': '0x36', 'EventName': 'UNC_C_TOR_OCCUPANCY.IRQ_HIT', 'PerPkg': '1', 'UMask': '0x11', 'Unit': 'CHA'}
# Skipping deprecated event at index 680: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_OCCUPANCY.IA_MISS', 'Counter': '0', 'Deprecated': '1', 'EventCode': '0x36', 'EventName': 'UNC_C_TOR_OCCUPANCY.IRQ_MISS', 'PerPkg': '1', 'UMask': '0x21', 'Unit': 'CHA'}
# Skipping deprecated event at index 681: {'BriefDescription': 'This event is deprecated.', 'Counter': '0', 'Deprecated': '1', 'EventCode': '0x36', 'EventName': 'UNC_C_TOR_OCCUPANCY.LOC_ALL', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x37', 'Unit': 'CHA'}
# Skipping deprecated event at index 682: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_OCCUPANCY.IA', 'Counter': '0', 'Deprecated': '1', 'EventCode': '0x36', 'EventName': 'UNC_C_TOR_OCCUPANCY.LOC_IA', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x31', 'Unit': 'CHA'}
# Skipping deprecated event at index 683: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_OCCUPANCY.IO', 'Counter': '0', 'Deprecated': '1', 'EventCode': '0x36', 'EventName': 'UNC_C_TOR_OCCUPANCY.LOC_IO', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x34', 'Unit': 'CHA'}
# Skipping deprecated event at index 684: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_OCCUPANCY.MISS', 'Counter': '0', 'Deprecated': '1', 'EventCode': '0x36', 'EventName': 'UNC_C_TOR_OCCUPANCY.MISS', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x20', 'Unit': 'CHA'}
# Skipping deprecated event at index 685: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_OCCUPANCY.PRQ', 'Counter': '0', 'Deprecated': '1', 'EventCode': '0x36', 'EventName': 'UNC_C_TOR_OCCUPANCY.PRQ', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 686: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_OCCUPANCY.IO_HIT', 'Counter': '0', 'Deprecated': '1', 'EventCode': '0x36', 'EventName': 'UNC_C_TOR_OCCUPANCY.PRQ_HIT', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x14', 'Unit': 'CHA'}
# Skipping deprecated event at index 687: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TOR_OCCUPANCY.IO_MISS', 'Counter': '0', 'Deprecated': '1', 'EventCode': '0x36', 'EventName': 'UNC_C_TOR_OCCUPANCY.PRQ_MISS', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x24', 'Unit': 'CHA'}
# Skipping deprecated event at index 688: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_AD_CRD_ACQUIRED.TGR0', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x80', 'EventName': 'UNC_H_AG0_AD_CRD_ACQUIRED.TGR0', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 689: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_AD_CRD_ACQUIRED.TGR1', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x80', 'EventName': 'UNC_H_AG0_AD_CRD_ACQUIRED.TGR1', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 690: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_AD_CRD_ACQUIRED.TGR2', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x80', 'EventName': 'UNC_H_AG0_AD_CRD_ACQUIRED.TGR2', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 691: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_AD_CRD_ACQUIRED.TGR3', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x80', 'EventName': 'UNC_H_AG0_AD_CRD_ACQUIRED.TGR3', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 692: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_AD_CRD_ACQUIRED.TGR4', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x80', 'EventName': 'UNC_H_AG0_AD_CRD_ACQUIRED.TGR4', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x10', 'Unit': 'CHA'}
# Skipping deprecated event at index 693: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_AD_CRD_ACQUIRED.TGR5', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x80', 'EventName': 'UNC_H_AG0_AD_CRD_ACQUIRED.TGR5', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x20', 'Unit': 'CHA'}
# Skipping deprecated event at index 694: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_AD_CRD_OCCUPANCY.TGR0', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x82', 'EventName': 'UNC_H_AG0_AD_CRD_OCCUPANCY.TGR0', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 695: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_AD_CRD_OCCUPANCY.TGR1', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x82', 'EventName': 'UNC_H_AG0_AD_CRD_OCCUPANCY.TGR1', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 696: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_AD_CRD_OCCUPANCY.TGR2', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x82', 'EventName': 'UNC_H_AG0_AD_CRD_OCCUPANCY.TGR2', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 697: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_AD_CRD_OCCUPANCY.TGR3', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x82', 'EventName': 'UNC_H_AG0_AD_CRD_OCCUPANCY.TGR3', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 698: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_AD_CRD_OCCUPANCY.TGR4', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x82', 'EventName': 'UNC_H_AG0_AD_CRD_OCCUPANCY.TGR4', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x10', 'Unit': 'CHA'}
# Skipping deprecated event at index 699: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_AD_CRD_OCCUPANCY.TGR5', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x82', 'EventName': 'UNC_H_AG0_AD_CRD_OCCUPANCY.TGR5', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x20', 'Unit': 'CHA'}
# Skipping deprecated event at index 700: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_BL_CRD_ACQUIRED.TGR0', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x88', 'EventName': 'UNC_H_AG0_BL_CRD_ACQUIRED.TGR0', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 701: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_BL_CRD_ACQUIRED.TGR1', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x88', 'EventName': 'UNC_H_AG0_BL_CRD_ACQUIRED.TGR1', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 702: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_BL_CRD_ACQUIRED.TGR2', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x88', 'EventName': 'UNC_H_AG0_BL_CRD_ACQUIRED.TGR2', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 703: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_BL_CRD_ACQUIRED.TGR3', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x88', 'EventName': 'UNC_H_AG0_BL_CRD_ACQUIRED.TGR3', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 704: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_BL_CRD_ACQUIRED.TGR4', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x88', 'EventName': 'UNC_H_AG0_BL_CRD_ACQUIRED.TGR4', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x10', 'Unit': 'CHA'}
# Skipping deprecated event at index 705: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_BL_CRD_ACQUIRED.TGR5', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x88', 'EventName': 'UNC_H_AG0_BL_CRD_ACQUIRED.TGR5', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x20', 'Unit': 'CHA'}
# Skipping deprecated event at index 706: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_BL_CRD_OCCUPANCY.TGR0', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x8A', 'EventName': 'UNC_H_AG0_BL_CRD_OCCUPANCY.TGR0', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 707: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_BL_CRD_OCCUPANCY.TGR1', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x8A', 'EventName': 'UNC_H_AG0_BL_CRD_OCCUPANCY.TGR1', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 708: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_BL_CRD_OCCUPANCY.TGR2', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x8A', 'EventName': 'UNC_H_AG0_BL_CRD_OCCUPANCY.TGR2', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 709: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_BL_CRD_OCCUPANCY.TGR3', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x8A', 'EventName': 'UNC_H_AG0_BL_CRD_OCCUPANCY.TGR3', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 710: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_BL_CRD_OCCUPANCY.TGR4', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x8A', 'EventName': 'UNC_H_AG0_BL_CRD_OCCUPANCY.TGR4', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x10', 'Unit': 'CHA'}
# Skipping deprecated event at index 711: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG0_BL_CRD_OCCUPANCY.TGR5', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x8A', 'EventName': 'UNC_H_AG0_BL_CRD_OCCUPANCY.TGR5', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x20', 'Unit': 'CHA'}
# Skipping deprecated event at index 712: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_AD_CRD_ACQUIRED.TGR0', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x84', 'EventName': 'UNC_H_AG1_AD_CRD_ACQUIRED.TGR0', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 713: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_AD_CRD_ACQUIRED.TGR1', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x84', 'EventName': 'UNC_H_AG1_AD_CRD_ACQUIRED.TGR1', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 714: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_AD_CRD_ACQUIRED.TGR2', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x84', 'EventName': 'UNC_H_AG1_AD_CRD_ACQUIRED.TGR2', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 715: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_AD_CRD_ACQUIRED.TGR3', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x84', 'EventName': 'UNC_H_AG1_AD_CRD_ACQUIRED.TGR3', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 716: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_AD_CRD_ACQUIRED.TGR4', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x84', 'EventName': 'UNC_H_AG1_AD_CRD_ACQUIRED.TGR4', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x10', 'Unit': 'CHA'}
# Skipping deprecated event at index 717: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_AD_CRD_ACQUIRED.TGR5', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x84', 'EventName': 'UNC_H_AG1_AD_CRD_ACQUIRED.TGR5', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x20', 'Unit': 'CHA'}
# Skipping deprecated event at index 718: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_AD_CRD_OCCUPANCY.TGR0', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x86', 'EventName': 'UNC_H_AG1_AD_CRD_OCCUPANCY.TGR0', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 719: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_AD_CRD_OCCUPANCY.TGR1', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x86', 'EventName': 'UNC_H_AG1_AD_CRD_OCCUPANCY.TGR1', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 720: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_AD_CRD_OCCUPANCY.TGR2', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x86', 'EventName': 'UNC_H_AG1_AD_CRD_OCCUPANCY.TGR2', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 721: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_AD_CRD_OCCUPANCY.TGR3', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x86', 'EventName': 'UNC_H_AG1_AD_CRD_OCCUPANCY.TGR3', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 722: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_AD_CRD_OCCUPANCY.TGR4', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x86', 'EventName': 'UNC_H_AG1_AD_CRD_OCCUPANCY.TGR4', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x10', 'Unit': 'CHA'}
# Skipping deprecated event at index 723: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_AD_CRD_OCCUPANCY.TGR5', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x86', 'EventName': 'UNC_H_AG1_AD_CRD_OCCUPANCY.TGR5', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x20', 'Unit': 'CHA'}
# Skipping deprecated event at index 724: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_BL_CRD_OCCUPANCY.TGR0', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x8E', 'EventName': 'UNC_H_AG1_BL_CRD_OCCUPANCY.TGR0', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 725: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_BL_CRD_OCCUPANCY.TGR1', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x8E', 'EventName': 'UNC_H_AG1_BL_CRD_OCCUPANCY.TGR1', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 726: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_BL_CRD_OCCUPANCY.TGR2', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x8E', 'EventName': 'UNC_H_AG1_BL_CRD_OCCUPANCY.TGR2', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 727: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_BL_CRD_OCCUPANCY.TGR3', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x8E', 'EventName': 'UNC_H_AG1_BL_CRD_OCCUPANCY.TGR3', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 728: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_BL_CRD_OCCUPANCY.TGR4', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x8E', 'EventName': 'UNC_H_AG1_BL_CRD_OCCUPANCY.TGR4', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x10', 'Unit': 'CHA'}
# Skipping deprecated event at index 729: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_BL_CRD_OCCUPANCY.TGR5', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x8E', 'EventName': 'UNC_H_AG1_BL_CRD_OCCUPANCY.TGR5', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x20', 'Unit': 'CHA'}
# Skipping deprecated event at index 730: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_BL_CREDITS_ACQUIRED.TGR0', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x8C', 'EventName': 'UNC_H_AG1_BL_CREDITS_ACQUIRED.TGR0', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 731: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_BL_CREDITS_ACQUIRED.TGR1', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x8C', 'EventName': 'UNC_H_AG1_BL_CREDITS_ACQUIRED.TGR1', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 732: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_BL_CREDITS_ACQUIRED.TGR2', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x8C', 'EventName': 'UNC_H_AG1_BL_CREDITS_ACQUIRED.TGR2', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 733: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_BL_CREDITS_ACQUIRED.TGR3', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x8C', 'EventName': 'UNC_H_AG1_BL_CREDITS_ACQUIRED.TGR3', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 734: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_BL_CREDITS_ACQUIRED.TGR4', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x8C', 'EventName': 'UNC_H_AG1_BL_CREDITS_ACQUIRED.TGR4', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x10', 'Unit': 'CHA'}
# Skipping deprecated event at index 735: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_AG1_BL_CREDITS_ACQUIRED.TGR5', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x8C', 'EventName': 'UNC_H_AG1_BL_CREDITS_ACQUIRED.TGR5', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x20', 'Unit': 'CHA'}
# Skipping deprecated event at index 736: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_BYPASS_CHA_IMC.INTERMEDIATE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x57', 'EventName': 'UNC_H_BYPASS_CHA_IMC.INTERMEDIATE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 737: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_BYPASS_CHA_IMC.NOT_TAKEN', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x57', 'EventName': 'UNC_H_BYPASS_CHA_IMC.NOT_TAKEN', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 738: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_BYPASS_CHA_IMC.TAKEN', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x57', 'EventName': 'UNC_H_BYPASS_CHA_IMC.TAKEN', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 739: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_CMS_CLOCKTICKS', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xC0', 'EventName': 'UNC_H_CLOCK', 'Experimental': '1', 'PerPkg': '1', 'Unit': 'CHA'}
# Skipping deprecated event at index 740: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_CORE_PMA.C1_STATE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x17', 'EventName': 'UNC_H_CORE_PMA.C1_STATE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 741: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_CORE_PMA.C1_TRANSITION', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x17', 'EventName': 'UNC_H_CORE_PMA.C1_TRANSITION', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 742: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_CORE_PMA.C6_STATE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x17', 'EventName': 'UNC_H_CORE_PMA.C6_STATE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 743: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_CORE_PMA.C6_TRANSITION', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x17', 'EventName': 'UNC_H_CORE_PMA.C6_TRANSITION', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 744: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_CORE_PMA.GV', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x17', 'EventName': 'UNC_H_CORE_PMA.GV', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x10', 'Unit': 'CHA'}
# Skipping deprecated event at index 745: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_CORE_SNP.ANY_GTONE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x33', 'EventName': 'UNC_H_CORE_SNP.ANY_GTONE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0xe2', 'Unit': 'CHA'}
# Skipping deprecated event at index 746: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_CORE_SNP.ANY_ONE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x33', 'EventName': 'UNC_H_CORE_SNP.ANY_ONE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0xe1', 'Unit': 'CHA'}
# Skipping deprecated event at index 747: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_CORE_SNP.ANY_REMOTE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x33', 'EventName': 'UNC_H_CORE_SNP.ANY_REMOTE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0xe4', 'Unit': 'CHA'}
# Skipping deprecated event at index 748: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_CORE_SNP.CORE_GTONE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x33', 'EventName': 'UNC_H_CORE_SNP.CORE_GTONE', 'PerPkg': '1', 'UMask': '0x42', 'Unit': 'CHA'}
# Skipping deprecated event at index 749: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_CORE_SNP.CORE_ONE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x33', 'EventName': 'UNC_H_CORE_SNP.CORE_ONE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x41', 'Unit': 'CHA'}
# Skipping deprecated event at index 750: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_CORE_SNP.CORE_REMOTE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x33', 'EventName': 'UNC_H_CORE_SNP.CORE_REMOTE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x44', 'Unit': 'CHA'}
# Skipping deprecated event at index 751: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_CORE_SNP.EVICT_GTONE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x33', 'EventName': 'UNC_H_CORE_SNP.EVICT_GTONE', 'PerPkg': '1', 'UMask': '0x82', 'Unit': 'CHA'}
# Skipping deprecated event at index 752: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_CORE_SNP.EVICT_ONE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x33', 'EventName': 'UNC_H_CORE_SNP.EVICT_ONE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x81', 'Unit': 'CHA'}
# Skipping deprecated event at index 753: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_CORE_SNP.EVICT_REMOTE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x33', 'EventName': 'UNC_H_CORE_SNP.EVICT_REMOTE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x84', 'Unit': 'CHA'}
# Skipping deprecated event at index 754: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_CORE_SNP.EXT_GTONE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x33', 'EventName': 'UNC_H_CORE_SNP.EXT_GTONE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x22', 'Unit': 'CHA'}
# Skipping deprecated event at index 755: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_CORE_SNP.EXT_ONE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x33', 'EventName': 'UNC_H_CORE_SNP.EXT_ONE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x21', 'Unit': 'CHA'}
# Skipping deprecated event at index 756: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_CORE_SNP.EXT_REMOTE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x33', 'EventName': 'UNC_H_CORE_SNP.EXT_REMOTE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x24', 'Unit': 'CHA'}
# Skipping deprecated event at index 757: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_COUNTER0_OCCUPANCY', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x1F', 'EventName': 'UNC_H_COUNTER0_OCCUPANCY', 'Experimental': '1', 'PerPkg': '1', 'Unit': 'CHA'}
# Skipping deprecated event at index 758: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_DIR_LOOKUP.NO_SNP', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x53', 'EventName': 'UNC_H_DIR_LOOKUP.NO_SNP', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 759: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_DIR_LOOKUP.SNP', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x53', 'EventName': 'UNC_H_DIR_LOOKUP.SNP', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 760: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_DIR_UPDATE.HA', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x54', 'EventName': 'UNC_H_DIR_UPDATE.HA', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 761: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_DIR_UPDATE.TOR', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x54', 'EventName': 'UNC_H_DIR_UPDATE.TOR', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 762: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_EGRESS_ORDERING.IV_SNOOPGO_DN', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xAE', 'EventName': 'UNC_H_EGRESS_ORDERING.IV_SNOOPGO_DN', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 763: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_EGRESS_ORDERING.IV_SNOOPGO_UP', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xAE', 'EventName': 'UNC_H_EGRESS_ORDERING.IV_SNOOPGO_UP', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 764: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_HITME_HIT.EX_RDS', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x5F', 'EventName': 'UNC_H_HITME_HIT.EX_RDS', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 765: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_HITME_HIT.SHARED_OWNREQ', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x5F', 'EventName': 'UNC_H_HITME_HIT.SHARED_OWNREQ', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 766: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_HITME_HIT.WBMTOE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x5F', 'EventName': 'UNC_H_HITME_HIT.WBMTOE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 767: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_HITME_HIT.WBMTOI_OR_S', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x5F', 'EventName': 'UNC_H_HITME_HIT.WBMTOI_OR_S', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x10', 'Unit': 'CHA'}
# Skipping deprecated event at index 768: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_HITME_LOOKUP.READ', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x5E', 'EventName': 'UNC_H_HITME_LOOKUP.READ', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 769: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_HITME_LOOKUP.WRITE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x5E', 'EventName': 'UNC_H_HITME_LOOKUP.WRITE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 770: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_HITME_MISS.NOTSHARED_RDINVOWN', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x60', 'EventName': 'UNC_H_HITME_MISS.NOTSHARED_RDINVOWN', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x40', 'Unit': 'CHA'}
# Skipping deprecated event at index 771: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_HITME_MISS.READ_OR_INV', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x60', 'EventName': 'UNC_H_HITME_MISS.READ_OR_INV', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x80', 'Unit': 'CHA'}
# Skipping deprecated event at index 772: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_HITME_MISS.SHARED_RDINVOWN', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x60', 'EventName': 'UNC_H_HITME_MISS.SHARED_RDINVOWN', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x20', 'Unit': 'CHA'}
# Skipping deprecated event at index 773: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_HITME_UPDATE.DEALLOCATE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x61', 'EventName': 'UNC_H_HITME_UPDATE.DEALLOCATE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x10', 'Unit': 'CHA'}
# Skipping deprecated event at index 774: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_HITME_UPDATE.DEALLOCATE_RSPFWDI_LOC', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x61', 'EventName': 'UNC_H_HITME_UPDATE.DEALLOCATE_RSPFWDI_LOC', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 775: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_HITME_UPDATE.RDINVOWN', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x61', 'EventName': 'UNC_H_HITME_UPDATE.RDINVOWN', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 776: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_HITME_UPDATE.RSPFWDI_REM', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x61', 'EventName': 'UNC_H_HITME_UPDATE.RSPFWDI_REM', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 777: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_HITME_UPDATE.SHARED', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x61', 'EventName': 'UNC_H_HITME_UPDATE.SHARED', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 778: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_HORZ_RING_AD_IN_USE.LEFT_EVEN', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xA7', 'EventName': 'UNC_H_HORZ_RING_AD_IN_USE.LEFT_EVEN', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# ...
# Skipping deprecated event at index 1154: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TxR_VERT_STARVED.AD_AG0', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x9A', 'EventName': 'UNC_H_TxR_VERT_STARVED.AD_AG0', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 1155: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TxR_VERT_STARVED.AD_AG1', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x9A', 'EventName': 'UNC_H_TxR_VERT_STARVED.AD_AG1', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x10', 'Unit': 'CHA'}
# Skipping deprecated event at index 1156: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TxR_VERT_STARVED.AK_AG0', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x9A', 'EventName': 'UNC_H_TxR_VERT_STARVED.AK_AG0', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 1157: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TxR_VERT_STARVED.AK_AG1', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x9A', 'EventName': 'UNC_H_TxR_VERT_STARVED.AK_AG1', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x20', 'Unit': 'CHA'}
# Skipping deprecated event at index 1158: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TxR_VERT_STARVED.BL_AG0', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x9A', 'EventName': 'UNC_H_TxR_VERT_STARVED.BL_AG0', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 1159: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TxR_VERT_STARVED.BL_AG1', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x9A', 'EventName': 'UNC_H_TxR_VERT_STARVED.BL_AG1', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x40', 'Unit': 'CHA'}
# Skipping deprecated event at index 1160: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_TxR_VERT_STARVED.IV', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x9A', 'EventName': 'UNC_H_TxR_VERT_STARVED.IV', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 1161: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_VERT_RING_AD_IN_USE.DN_EVEN', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xA6', 'EventName': 'UNC_H_VERT_RING_AD_IN_USE.DN_EVEN', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 1162: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_VERT_RING_AD_IN_USE.DN_ODD', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xA6', 'EventName': 'UNC_H_VERT_RING_AD_IN_USE.DN_ODD', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 1163: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_VERT_RING_AD_IN_USE.UP_EVEN', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xA6', 'EventName': 'UNC_H_VERT_RING_AD_IN_USE.UP_EVEN', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 1164: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_VERT_RING_AD_IN_USE.UP_ODD', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xA6', 'EventName': 'UNC_H_VERT_RING_AD_IN_USE.UP_ODD', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 1165: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_VERT_RING_AK_IN_USE.DN_EVEN', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xA8', 'EventName': 'UNC_H_VERT_RING_AK_IN_USE.DN_EVEN', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 1166: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_VERT_RING_AK_IN_USE.DN_ODD', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xA8', 'EventName': 'UNC_H_VERT_RING_AK_IN_USE.DN_ODD', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 1167: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_VERT_RING_AK_IN_USE.UP_EVEN', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xA8', 'EventName': 'UNC_H_VERT_RING_AK_IN_USE.UP_EVEN', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 1168: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_VERT_RING_AK_IN_USE.UP_ODD', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xA8', 'EventName': 'UNC_H_VERT_RING_AK_IN_USE.UP_ODD', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 1169: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_VERT_RING_BL_IN_USE.DN_EVEN', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xAA', 'EventName': 'UNC_H_VERT_RING_BL_IN_USE.DN_EVEN', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 1170: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_VERT_RING_BL_IN_USE.DN_ODD', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xAA', 'EventName': 'UNC_H_VERT_RING_BL_IN_USE.DN_ODD', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 1171: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_VERT_RING_BL_IN_USE.UP_EVEN', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xAA', 'EventName': 'UNC_H_VERT_RING_BL_IN_USE.UP_EVEN', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 1172: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_VERT_RING_BL_IN_USE.UP_ODD', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xAA', 'EventName': 'UNC_H_VERT_RING_BL_IN_USE.UP_ODD', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 1173: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_VERT_RING_IV_IN_USE.DN', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xAC', 'EventName': 'UNC_H_VERT_RING_IV_IN_USE.DN', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 1174: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_VERT_RING_IV_IN_USE.UP', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0xAC', 'EventName': 'UNC_H_VERT_RING_IV_IN_USE.UP', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 1175: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_WB_PUSH_MTOI.LLC', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x56', 'EventName': 'UNC_H_WB_PUSH_MTOI.LLC', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 1176: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_WB_PUSH_MTOI.MEM', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x56', 'EventName': 'UNC_H_WB_PUSH_MTOI.MEM', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 1177: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_WRITE_NO_CREDITS.EDC0_SMI2', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x5A', 'EventName': 'UNC_H_WRITE_NO_CREDITS.EDC0_SMI2', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x4', 'Unit': 'CHA'}
# Skipping deprecated event at index 1178: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_WRITE_NO_CREDITS.EDC1_SMI3', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x5A', 'EventName': 'UNC_H_WRITE_NO_CREDITS.EDC1_SMI3', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x8', 'Unit': 'CHA'}
# Skipping deprecated event at index 1179: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_WRITE_NO_CREDITS.EDC2_SMI4', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x5A', 'EventName': 'UNC_H_WRITE_NO_CREDITS.EDC2_SMI4', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x10', 'Unit': 'CHA'}
# Skipping deprecated event at index 1180: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_WRITE_NO_CREDITS.EDC3_SMI5', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x5A', 'EventName': 'UNC_H_WRITE_NO_CREDITS.EDC3_SMI5', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x20', 'Unit': 'CHA'}
# Skipping deprecated event at index 1181: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_WRITE_NO_CREDITS.MC0_SMI0', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x5A', 'EventName': 'UNC_H_WRITE_NO_CREDITS.MC0_SMI0', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x1', 'Unit': 'CHA'}
# Skipping deprecated event at index 1182: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_WRITE_NO_CREDITS.MC1_SMI1', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x5A', 'EventName': 'UNC_H_WRITE_NO_CREDITS.MC1_SMI1', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x2', 'Unit': 'CHA'}
# Skipping deprecated event at index 1183: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.ANY_RSPI_FWDFE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.ANY_RSPI_FWDFE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0xe4', 'Unit': 'CHA'}
# Skipping deprecated event at index 1184: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.ANY_RSPI_FWDM', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.ANY_RSPI_FWDM', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0xf0', 'Unit': 'CHA'}
# Skipping deprecated event at index 1185: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.ANY_RSPS_FWDFE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.ANY_RSPS_FWDFE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0xe2', 'Unit': 'CHA'}
# Skipping deprecated event at index 1186: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.ANY_RSPS_FWDM', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.ANY_RSPS_FWDM', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0xe8', 'Unit': 'CHA'}
# Skipping deprecated event at index 1187: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.ANY_RSP_HITFSE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.ANY_RSP_HITFSE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0xe1', 'Unit': 'CHA'}
# Skipping deprecated event at index 1188: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.CORE_RSPI_FWDFE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.CORE_RSPI_FWDFE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x44', 'Unit': 'CHA'}
# Skipping deprecated event at index 1189: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.CORE_RSPI_FWDM', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.CORE_RSPI_FWDM', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x50', 'Unit': 'CHA'}
# Skipping deprecated event at index 1190: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.CORE_RSPS_FWDFE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.CORE_RSPS_FWDFE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x42', 'Unit': 'CHA'}
# Skipping deprecated event at index 1191: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.CORE_RSPS_FWDM', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.CORE_RSPS_FWDM', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x48', 'Unit': 'CHA'}
# Skipping deprecated event at index 1192: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.CORE_RSP_HITFSE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.CORE_RSP_HITFSE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x41', 'Unit': 'CHA'}
# Skipping deprecated event at index 1193: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.EVICT_RSPI_FWDFE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.EVICT_RSPI_FWDFE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x84', 'Unit': 'CHA'}
# Skipping deprecated event at index 1194: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.EVICT_RSPI_FWDM', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.EVICT_RSPI_FWDM', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x90', 'Unit': 'CHA'}
# Skipping deprecated event at index 1195: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.EVICT_RSPS_FWDFE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.EVICT_RSPS_FWDFE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x82', 'Unit': 'CHA'}
# Skipping deprecated event at index 1196: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.EVICT_RSPS_FWDM', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.EVICT_RSPS_FWDM', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x88', 'Unit': 'CHA'}
# Skipping deprecated event at index 1197: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.EVICT_RSP_HITFSE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.EVICT_RSP_HITFSE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x81', 'Unit': 'CHA'}
# Skipping deprecated event at index 1198: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.EXT_RSPI_FWDFE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.EXT_RSPI_FWDFE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x24', 'Unit': 'CHA'}
# Skipping deprecated event at index 1199: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.EXT_RSPI_FWDM', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.EXT_RSPI_FWDM', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x30', 'Unit': 'CHA'}
# Skipping deprecated event at index 1200: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.EXT_RSPS_FWDFE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.EXT_RSPS_FWDFE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x22', 'Unit': 'CHA'}
# Skipping deprecated event at index 1201: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.EXT_RSPS_FWDM', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.EXT_RSPS_FWDM', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x28', 'Unit': 'CHA'}
# Skipping deprecated event at index 1202: {'BriefDescription': 'This event is deprecated. Refer to new event UNC_CHA_XSNP_RESP.EXT_RSP_HITFSE', 'Counter': '0,1,2,3', 'Deprecated': '1', 'EventCode': '0x32', 'EventName': 'UNC_H_XSNP_RESP.EXT_RSP_HITFSE', 'Experimental': '1', 'PerPkg': '1', 'UMask': '0x21', 'Unit': 'CHA'}
# Updated JSON file saved to cha_events_clx_parsed.json
# Updated JSON file saved to cha_events_spr_parsed.json

# %%
import json

# %%
def generate_event_json():
    base_event = {
        "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
        "EventCode": "0x61",
        "Unit": "CHA"
    }
    
    events = []
    for umask in range(0x00, 0x100):  # 0x00 to 0xff (inclusive)
        event = base_event.copy()
        event["UMask"] = f"0x{umask:02x}"
        event["EventName"] = f"UNC_CHA_HITME_UPDATE.MASK_{umask:02x}"
        events.append(event)
    
    json_output = json.dumps(events, indent=4)
    print(json_output)
    
    with open("events.json", "w") as f:
        f.write(json_output)
    
    print("Generated events.json successfully!")

if __name__ == "__main__":
    generate_event_json()
# Out:
# [
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x00",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_00"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x01",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_01"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x02",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_02"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x03",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_03"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x04",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_04"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x05",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_05"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x06",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_06"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x07",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_07"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x08",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_08"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x09",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_09"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x0a",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_0a"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x0b",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_0b"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x0c",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_0c"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x0d",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_0d"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x0e",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_0e"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x0f",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_0f"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x10",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_10"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x11",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_11"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x12",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_12"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x13",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_13"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x14",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_14"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x15",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_15"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x16",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_16"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x17",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_17"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x18",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_18"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x19",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_19"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x1a",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_1a"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x1b",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_1b"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x1c",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_1c"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x1d",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_1d"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x1e",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_1e"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x1f",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_1f"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x20",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_20"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x21",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_21"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x22",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_22"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x23",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_23"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x24",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_24"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x25",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_25"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x26",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_26"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x27",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_27"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x28",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_28"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x29",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_29"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x2a",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_2a"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x2b",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_2b"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x2c",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_2c"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x2d",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_2d"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x2e",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_2e"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x2f",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_2f"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x30",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_30"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x31",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_31"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x32",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_32"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x33",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_33"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x34",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_34"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x35",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_35"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x36",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_36"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x37",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_37"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x38",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_38"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x39",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_39"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x3a",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_3a"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x3b",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_3b"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x3c",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_3c"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x3d",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_3d"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x3e",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_3e"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x3f",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_3f"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x40",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_40"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x41",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_41"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x42",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_42"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x43",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_43"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x44",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_44"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x45",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_45"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x46",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_46"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x47",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_47"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x48",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_48"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x49",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_49"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x4a",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_4a"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x4b",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_4b"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x4c",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_4c"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x4d",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_4d"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x4e",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_4e"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x4f",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_4f"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x50",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_50"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x51",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_51"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x52",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_52"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x53",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_53"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x54",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_54"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x55",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_55"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x56",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_56"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x57",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_57"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x58",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_58"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x59",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_59"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x5a",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_5a"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x5b",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_5b"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x5c",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_5c"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x5d",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_5d"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x5e",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_5e"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x5f",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_5f"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x60",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_60"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x61",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_61"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x62",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_62"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x63",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_63"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x64",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_64"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x65",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_65"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x66",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_66"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x67",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_67"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x68",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_68"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x69",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_69"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x6a",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_6a"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x6b",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_6b"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x6c",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_6c"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x6d",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_6d"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x6e",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_6e"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x6f",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_6f"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x70",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_70"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x71",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_71"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x72",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_72"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x73",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_73"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x74",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_74"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x75",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_75"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x76",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_76"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x77",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_77"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x78",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_78"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x79",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_79"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x7a",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_7a"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x7b",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_7b"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x7c",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_7c"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x7d",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_7d"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x7e",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_7e"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x7f",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_7f"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x80",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_80"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x81",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_81"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x82",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_82"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x83",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_83"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x84",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_84"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x85",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_85"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x86",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_86"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x87",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_87"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x88",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_88"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x89",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_89"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x8a",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_8a"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x8b",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_8b"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x8c",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_8c"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x8d",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_8d"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x8e",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_8e"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x8f",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_8f"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x90",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_90"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x91",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_91"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x92",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_92"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x93",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_93"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x94",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_94"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x95",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_95"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x96",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_96"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x97",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_97"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x98",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_98"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x99",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_99"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x9a",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_9a"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x9b",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_9b"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x9c",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_9c"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x9d",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_9d"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x9e",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_9e"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0x9f",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_9f"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xa0",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_a0"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xa1",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_a1"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xa2",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_a2"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xa3",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_a3"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xa4",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_a4"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xa5",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_a5"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xa6",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_a6"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xa7",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_a7"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xa8",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_a8"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xa9",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_a9"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xaa",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_aa"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xab",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_ab"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xac",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_ac"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xad",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_ad"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xae",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_ae"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xaf",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_af"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xb0",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_b0"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xb1",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_b1"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xb2",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_b2"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xb3",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_b3"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xb4",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_b4"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xb5",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_b5"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xb6",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_b6"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xb7",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_b7"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xb8",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_b8"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xb9",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_b9"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xba",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_ba"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xbb",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_bb"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xbc",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_bc"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xbd",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_bd"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xbe",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_be"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xbf",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_bf"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xc0",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_c0"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xc1",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_c1"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xc2",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_c2"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xc3",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_c3"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xc4",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_c4"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xc5",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_c5"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xc6",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_c6"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xc7",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_c7"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xc8",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_c8"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xc9",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_c9"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xca",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_ca"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xcb",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_cb"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xcc",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_cc"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xcd",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_cd"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xce",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_ce"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xcf",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_cf"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xd0",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_d0"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xd1",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_d1"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xd2",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_d2"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xd3",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_d3"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xd4",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_d4"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xd5",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_d5"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xd6",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_d6"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xd7",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_d7"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xd8",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_d8"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xd9",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_d9"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xda",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_da"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xdb",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_db"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xdc",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_dc"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xdd",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_dd"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xde",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_de"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xdf",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_df"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xe0",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_e0"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xe1",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_e1"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xe2",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_e2"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xe3",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_e3"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xe4",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_e4"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xe5",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_e5"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xe6",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_e6"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xe7",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_e7"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xe8",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_e8"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xe9",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_e9"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xea",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_ea"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xeb",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_eb"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xec",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_ec"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xed",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_ed"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xee",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_ee"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xef",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_ef"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xf0",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_f0"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xf1",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_f1"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xf2",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_f2"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xf3",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_f3"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xf4",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_f4"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xf5",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_f5"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xf6",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_f6"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xf7",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_f7"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xf8",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_f8"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xf9",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_f9"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xfa",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_fa"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xfb",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_fb"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xfc",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_fc"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xfd",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_fd"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xfe",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_fe"
#     },
#     {
#         "BriefDescription": "Aggregated event for UNC_CHA_HITME_UPDATE",
#         "EventCode": "0x61",
#         "Unit": "CHA",
#         "UMask": "0xff",
#         "EventName": "UNC_CHA_HITME_UPDATE.MASK_ff"
#     }
# ]
# Generated events.json successfully!

# %%
for umask in range(0x00, 0x100):  # 0x00 to 0xff (inclusive)
    print(f"UNC_CHA_HITME_MISS.MASK_{umask:02x}")
# Out:
# UNC_CHA_HITME_MISS.MASK_00
# UNC_CHA_HITME_MISS.MASK_01
# UNC_CHA_HITME_MISS.MASK_02
# UNC_CHA_HITME_MISS.MASK_03
# UNC_CHA_HITME_MISS.MASK_04
# UNC_CHA_HITME_MISS.MASK_05
# UNC_CHA_HITME_MISS.MASK_06
# UNC_CHA_HITME_MISS.MASK_07
# UNC_CHA_HITME_MISS.MASK_08
# UNC_CHA_HITME_MISS.MASK_09
# UNC_CHA_HITME_MISS.MASK_0a
# UNC_CHA_HITME_MISS.MASK_0b
# UNC_CHA_HITME_MISS.MASK_0c
# UNC_CHA_HITME_MISS.MASK_0d
# UNC_CHA_HITME_MISS.MASK_0e
# UNC_CHA_HITME_MISS.MASK_0f
# UNC_CHA_HITME_MISS.MASK_10
# UNC_CHA_HITME_MISS.MASK_11
# UNC_CHA_HITME_MISS.MASK_12
# UNC_CHA_HITME_MISS.MASK_13
# UNC_CHA_HITME_MISS.MASK_14
# UNC_CHA_HITME_MISS.MASK_15
# UNC_CHA_HITME_MISS.MASK_16
# UNC_CHA_HITME_MISS.MASK_17
# UNC_CHA_HITME_MISS.MASK_18
# UNC_CHA_HITME_MISS.MASK_19
# UNC_CHA_HITME_MISS.MASK_1a
# UNC_CHA_HITME_MISS.MASK_1b
# UNC_CHA_HITME_MISS.MASK_1c
# UNC_CHA_HITME_MISS.MASK_1d
# UNC_CHA_HITME_MISS.MASK_1e
# UNC_CHA_HITME_MISS.MASK_1f
# UNC_CHA_HITME_MISS.MASK_20
# UNC_CHA_HITME_MISS.MASK_21
# UNC_CHA_HITME_MISS.MASK_22
# UNC_CHA_HITME_MISS.MASK_23
# UNC_CHA_HITME_MISS.MASK_24
# UNC_CHA_HITME_MISS.MASK_25
# UNC_CHA_HITME_MISS.MASK_26
# UNC_CHA_HITME_MISS.MASK_27
# UNC_CHA_HITME_MISS.MASK_28
# UNC_CHA_HITME_MISS.MASK_29
# UNC_CHA_HITME_MISS.MASK_2a
# UNC_CHA_HITME_MISS.MASK_2b
# UNC_CHA_HITME_MISS.MASK_2c
# UNC_CHA_HITME_MISS.MASK_2d
# UNC_CHA_HITME_MISS.MASK_2e
# UNC_CHA_HITME_MISS.MASK_2f
# UNC_CHA_HITME_MISS.MASK_30
# UNC_CHA_HITME_MISS.MASK_31
# UNC_CHA_HITME_MISS.MASK_32
# UNC_CHA_HITME_MISS.MASK_33
# UNC_CHA_HITME_MISS.MASK_34
# UNC_CHA_HITME_MISS.MASK_35
# UNC_CHA_HITME_MISS.MASK_36
# UNC_CHA_HITME_MISS.MASK_37
# UNC_CHA_HITME_MISS.MASK_38
# UNC_CHA_HITME_MISS.MASK_39
# UNC_CHA_HITME_MISS.MASK_3a
# UNC_CHA_HITME_MISS.MASK_3b
# UNC_CHA_HITME_MISS.MASK_3c
# UNC_CHA_HITME_MISS.MASK_3d
# UNC_CHA_HITME_MISS.MASK_3e
# UNC_CHA_HITME_MISS.MASK_3f
# UNC_CHA_HITME_MISS.MASK_40
# UNC_CHA_HITME_MISS.MASK_41
# UNC_CHA_HITME_MISS.MASK_42
# UNC_CHA_HITME_MISS.MASK_43
# UNC_CHA_HITME_MISS.MASK_44
# UNC_CHA_HITME_MISS.MASK_45
# UNC_CHA_HITME_MISS.MASK_46
# UNC_CHA_HITME_MISS.MASK_47
# UNC_CHA_HITME_MISS.MASK_48
# UNC_CHA_HITME_MISS.MASK_49
# UNC_CHA_HITME_MISS.MASK_4a
# UNC_CHA_HITME_MISS.MASK_4b
# UNC_CHA_HITME_MISS.MASK_4c
# UNC_CHA_HITME_MISS.MASK_4d
# UNC_CHA_HITME_MISS.MASK_4e
# UNC_CHA_HITME_MISS.MASK_4f
# UNC_CHA_HITME_MISS.MASK_50
# UNC_CHA_HITME_MISS.MASK_51
# UNC_CHA_HITME_MISS.MASK_52
# UNC_CHA_HITME_MISS.MASK_53
# UNC_CHA_HITME_MISS.MASK_54
# UNC_CHA_HITME_MISS.MASK_55
# UNC_CHA_HITME_MISS.MASK_56
# UNC_CHA_HITME_MISS.MASK_57
# UNC_CHA_HITME_MISS.MASK_58
# UNC_CHA_HITME_MISS.MASK_59
# UNC_CHA_HITME_MISS.MASK_5a
# UNC_CHA_HITME_MISS.MASK_5b
# UNC_CHA_HITME_MISS.MASK_5c
# UNC_CHA_HITME_MISS.MASK_5d
# UNC_CHA_HITME_MISS.MASK_5e
# UNC_CHA_HITME_MISS.MASK_5f
# UNC_CHA_HITME_MISS.MASK_60
# UNC_CHA_HITME_MISS.MASK_61
# UNC_CHA_HITME_MISS.MASK_62
# UNC_CHA_HITME_MISS.MASK_63
# UNC_CHA_HITME_MISS.MASK_64
# UNC_CHA_HITME_MISS.MASK_65
# UNC_CHA_HITME_MISS.MASK_66
# UNC_CHA_HITME_MISS.MASK_67
# UNC_CHA_HITME_MISS.MASK_68
# UNC_CHA_HITME_MISS.MASK_69
# UNC_CHA_HITME_MISS.MASK_6a
# UNC_CHA_HITME_MISS.MASK_6b
# UNC_CHA_HITME_MISS.MASK_6c
# UNC_CHA_HITME_MISS.MASK_6d
# UNC_CHA_HITME_MISS.MASK_6e
# UNC_CHA_HITME_MISS.MASK_6f
# UNC_CHA_HITME_MISS.MASK_70
# UNC_CHA_HITME_MISS.MASK_71
# UNC_CHA_HITME_MISS.MASK_72
# UNC_CHA_HITME_MISS.MASK_73
# UNC_CHA_HITME_MISS.MASK_74
# UNC_CHA_HITME_MISS.MASK_75
# UNC_CHA_HITME_MISS.MASK_76
# UNC_CHA_HITME_MISS.MASK_77
# UNC_CHA_HITME_MISS.MASK_78
# UNC_CHA_HITME_MISS.MASK_79
# UNC_CHA_HITME_MISS.MASK_7a
# UNC_CHA_HITME_MISS.MASK_7b
# UNC_CHA_HITME_MISS.MASK_7c
# UNC_CHA_HITME_MISS.MASK_7d
# UNC_CHA_HITME_MISS.MASK_7e
# UNC_CHA_HITME_MISS.MASK_7f
# UNC_CHA_HITME_MISS.MASK_80
# UNC_CHA_HITME_MISS.MASK_81
# UNC_CHA_HITME_MISS.MASK_82
# UNC_CHA_HITME_MISS.MASK_83
# UNC_CHA_HITME_MISS.MASK_84
# UNC_CHA_HITME_MISS.MASK_85
# UNC_CHA_HITME_MISS.MASK_86
# UNC_CHA_HITME_MISS.MASK_87
# UNC_CHA_HITME_MISS.MASK_88
# UNC_CHA_HITME_MISS.MASK_89
# UNC_CHA_HITME_MISS.MASK_8a
# UNC_CHA_HITME_MISS.MASK_8b
# UNC_CHA_HITME_MISS.MASK_8c
# UNC_CHA_HITME_MISS.MASK_8d
# UNC_CHA_HITME_MISS.MASK_8e
# UNC_CHA_HITME_MISS.MASK_8f
# UNC_CHA_HITME_MISS.MASK_90
# UNC_CHA_HITME_MISS.MASK_91
# UNC_CHA_HITME_MISS.MASK_92
# UNC_CHA_HITME_MISS.MASK_93
# UNC_CHA_HITME_MISS.MASK_94
# UNC_CHA_HITME_MISS.MASK_95
# UNC_CHA_HITME_MISS.MASK_96
# UNC_CHA_HITME_MISS.MASK_97
# UNC_CHA_HITME_MISS.MASK_98
# UNC_CHA_HITME_MISS.MASK_99
# UNC_CHA_HITME_MISS.MASK_9a
# UNC_CHA_HITME_MISS.MASK_9b
# UNC_CHA_HITME_MISS.MASK_9c
# UNC_CHA_HITME_MISS.MASK_9d
# UNC_CHA_HITME_MISS.MASK_9e
# UNC_CHA_HITME_MISS.MASK_9f
# UNC_CHA_HITME_MISS.MASK_a0
# UNC_CHA_HITME_MISS.MASK_a1
# UNC_CHA_HITME_MISS.MASK_a2
# UNC_CHA_HITME_MISS.MASK_a3
# UNC_CHA_HITME_MISS.MASK_a4
# UNC_CHA_HITME_MISS.MASK_a5
# UNC_CHA_HITME_MISS.MASK_a6
# UNC_CHA_HITME_MISS.MASK_a7
# UNC_CHA_HITME_MISS.MASK_a8
# UNC_CHA_HITME_MISS.MASK_a9
# UNC_CHA_HITME_MISS.MASK_aa
# UNC_CHA_HITME_MISS.MASK_ab
# UNC_CHA_HITME_MISS.MASK_ac
# UNC_CHA_HITME_MISS.MASK_ad
# UNC_CHA_HITME_MISS.MASK_ae
# UNC_CHA_HITME_MISS.MASK_af
# UNC_CHA_HITME_MISS.MASK_b0
# UNC_CHA_HITME_MISS.MASK_b1
# UNC_CHA_HITME_MISS.MASK_b2
# UNC_CHA_HITME_MISS.MASK_b3
# UNC_CHA_HITME_MISS.MASK_b4
# UNC_CHA_HITME_MISS.MASK_b5
# UNC_CHA_HITME_MISS.MASK_b6
# UNC_CHA_HITME_MISS.MASK_b7
# UNC_CHA_HITME_MISS.MASK_b8
# UNC_CHA_HITME_MISS.MASK_b9
# UNC_CHA_HITME_MISS.MASK_ba
# UNC_CHA_HITME_MISS.MASK_bb
# UNC_CHA_HITME_MISS.MASK_bc
# UNC_CHA_HITME_MISS.MASK_bd
# UNC_CHA_HITME_MISS.MASK_be
# UNC_CHA_HITME_MISS.MASK_bf
# UNC_CHA_HITME_MISS.MASK_c0
# UNC_CHA_HITME_MISS.MASK_c1
# UNC_CHA_HITME_MISS.MASK_c2
# UNC_CHA_HITME_MISS.MASK_c3
# UNC_CHA_HITME_MISS.MASK_c4
# UNC_CHA_HITME_MISS.MASK_c5
# UNC_CHA_HITME_MISS.MASK_c6
# UNC_CHA_HITME_MISS.MASK_c7
# UNC_CHA_HITME_MISS.MASK_c8
# UNC_CHA_HITME_MISS.MASK_c9
# UNC_CHA_HITME_MISS.MASK_ca
# UNC_CHA_HITME_MISS.MASK_cb
# UNC_CHA_HITME_MISS.MASK_cc
# UNC_CHA_HITME_MISS.MASK_cd
# UNC_CHA_HITME_MISS.MASK_ce
# UNC_CHA_HITME_MISS.MASK_cf
# UNC_CHA_HITME_MISS.MASK_d0
# UNC_CHA_HITME_MISS.MASK_d1
# UNC_CHA_HITME_MISS.MASK_d2
# UNC_CHA_HITME_MISS.MASK_d3
# UNC_CHA_HITME_MISS.MASK_d4
# UNC_CHA_HITME_MISS.MASK_d5
# UNC_CHA_HITME_MISS.MASK_d6
# UNC_CHA_HITME_MISS.MASK_d7
# UNC_CHA_HITME_MISS.MASK_d8
# UNC_CHA_HITME_MISS.MASK_d9
# UNC_CHA_HITME_MISS.MASK_da
# UNC_CHA_HITME_MISS.MASK_db
# UNC_CHA_HITME_MISS.MASK_dc
# UNC_CHA_HITME_MISS.MASK_dd
# UNC_CHA_HITME_MISS.MASK_de
# UNC_CHA_HITME_MISS.MASK_df
# UNC_CHA_HITME_MISS.MASK_e0
# UNC_CHA_HITME_MISS.MASK_e1
# UNC_CHA_HITME_MISS.MASK_e2
# UNC_CHA_HITME_MISS.MASK_e3
# UNC_CHA_HITME_MISS.MASK_e4
# UNC_CHA_HITME_MISS.MASK_e5
# UNC_CHA_HITME_MISS.MASK_e6
# UNC_CHA_HITME_MISS.MASK_e7
# UNC_CHA_HITME_MISS.MASK_e8
# UNC_CHA_HITME_MISS.MASK_e9
# UNC_CHA_HITME_MISS.MASK_ea
# UNC_CHA_HITME_MISS.MASK_eb
# UNC_CHA_HITME_MISS.MASK_ec
# UNC_CHA_HITME_MISS.MASK_ed
# UNC_CHA_HITME_MISS.MASK_ee
# UNC_CHA_HITME_MISS.MASK_ef
# UNC_CHA_HITME_MISS.MASK_f0
# UNC_CHA_HITME_MISS.MASK_f1
# UNC_CHA_HITME_MISS.MASK_f2
# UNC_CHA_HITME_MISS.MASK_f3
# UNC_CHA_HITME_MISS.MASK_f4
# UNC_CHA_HITME_MISS.MASK_f5
# UNC_CHA_HITME_MISS.MASK_f6
# UNC_CHA_HITME_MISS.MASK_f7
# UNC_CHA_HITME_MISS.MASK_f8
# UNC_CHA_HITME_MISS.MASK_f9
# UNC_CHA_HITME_MISS.MASK_fa
# UNC_CHA_HITME_MISS.MASK_fb
# UNC_CHA_HITME_MISS.MASK_fc
# UNC_CHA_HITME_MISS.MASK_fd
# UNC_CHA_HITME_MISS.MASK_fe
# UNC_CHA_HITME_MISS.MASK_ff
